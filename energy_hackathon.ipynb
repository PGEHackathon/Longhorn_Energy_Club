# %%
import os                                               # to set current working directory 
import numpy as np                                      # arrays and matrix math
import pandas as pd                                     # DataFrames
import matplotlib.pyplot as plt 

import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Well_Log/WP0.csv")

# %%
df
# Out:
#          MD(ft)   PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# 0   4597.471739 -999.000000              -999     2.700700   75.056761
# 1   4604.031739    0.087413              -999     2.819380   85.369586
# 2   4610.591739 -999.000000              -999     2.798909  124.121043
# 3   4617.151739    0.059590              -999     2.575396  114.571242
# 4   4623.711739 -999.000000              -999     2.895991  145.921799
# 5   4630.271739    0.082269              -999     2.831982  113.233625
# 6   4636.831739 -999.000000              -999     2.774357  113.594556
# 7   4643.391739    0.062989              -999     2.727031  121.931755
# 8   4649.951739 -999.000000              -999     2.926972  121.318158
# 9   4656.511739    0.067931              -999     2.974074  140.274713
# 10  4663.071739 -999.000000              -999     2.496010  124.821073
# 11  4669.631739    0.069750              -999     2.819388   85.366831
# ...

# %%
df_AI = pd.read_csv("AI.csv")

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)
# 0               6248.696838           6289.521004
# ...

# %%
df_AI.columns
# Out:
# Index(['X(ft)', 'Y(ft)', 'AI_lower(2012-01-01)', 'AI_upper(2012-01-01)',
#        'AI_lower(2021-12-20)', 'AI_upper(2021-12-20)'],
#       dtype='object')

# %%
df_AI.columns
# Out:
# Index(['X(ft)', 'Y(ft)', 'AI_lower(2012-01-01)', 'AI_upper(2012-01-01)',
#        'AI_lower(2021-12-20)', 'AI_upper(2021-12-20)'],
#       dtype='object')

# %%
df_AI["lower_diff_year"] = df_AI['AI_lower(2021-12-20)'] - df_AI['AI_lower(2012-01-01)']

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year
# ...

# %%
df_AI["upper_diff_year"] = df_AI['AI_upper(2021-12-20)'] - df_AI['AI_upper(2012-01-01)']

# %%
df_AI["upper_diff_year"]
# Out:
# 0        25.757784
# 1        25.708269
# 2        25.554874
# 3        25.307272
# 4        24.967225
#            ...
# 51195   -11.569660
# 51196   -11.892639
# 51197   -12.125806
# 51198   -12.268385
# 51199   -12.316070
# Name: upper_diff_year, Length: 51200, dtype: float64

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year  \
# ...

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year  \
# ...

# %%
df_AI.to_csv('diff_AI.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# # create some random data; replace that by your actual dataset
# data = pd.DataFrame(np.random.rand(11, 5), columns=['A', 'B', 'C', 'D', 'E'], index = range(2000, 2011, 1))

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_lower(2012-01-01)')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_lower(2021-12-20)')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_upper(2012-01-01)')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_upper(2021-12-20)')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'lower_diff_year')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'upper_diff_year')
ax = sns.heatmap(table)
ax.invert_yaxis()
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

# %%
df_wells = pd.read_csv("Well_Head_and_Completion.csv")

# %%
df_wells
# Out:
#     WELL      X(ft)     Y(ft) Completion  Elevation Kelly Bushing (ft)
# 0    WP0  137106.82  83818.47      Upper                        193.32
# 1    WP1  132460.98  85832.77      Upper                        187.15
# 2    WP2  133634.00  82144.52      Upper                        164.55
# 3    WP3  140892.57  81747.12      Lower                        179.92
# 4    WP4  109951.43  89343.45      Lower                        186.21
# 5    WP5  123950.95  92227.31      Lower                        172.80
# 6    WP6  111035.32  88692.32      Lower                        182.66
# 7    WP7  112439.69  85560.85      Lower                        181.09
# 8    WP8  127369.74  91739.99      Upper                        180.04
# 9    WP9  115943.69  86730.44      Lower                        178.25
# 10  WP10  134042.86  82411.27      Upper                        184.33
# 11  WP11  115725.49  86866.60      Upper                        192.03
# ...

# %%
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1)
color = ['green' if diff > 80 else 'blue' for diff in df_AI['lower_diff_year']]
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.show()

# coordinates for center
# clat = df_wells["Latitude"].mean()
# clon = df_wells["Longitude"].mean()

# # create map
# m = folium.Map(location=[clat,clon], zoom_start=15)

# # display
# display(m)

color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1)
color = ['green' if diff > 30 else 'blue' for diff in df_AI['upper_diff_year']]
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.show()
