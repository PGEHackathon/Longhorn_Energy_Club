# %%
import os                                               # to set current working directory 
import numpy as np                                      # arrays and matrix math
import pandas as pd                                     # DataFrames
import matplotlib.pyplot as plt 

import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
#open one well log data and view it
df = pd.read_csv("Well_Log/WP0.csv")

# %%
df
# Out:
#          MD(ft)   PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# 0   4597.471739 -999.000000              -999     2.700700   75.056761
# 1   4604.031739    0.087413              -999     2.819380   85.369586
# 2   4610.591739 -999.000000              -999     2.798909  124.121043
# 3   4617.151739    0.059590              -999     2.575396  114.571242
# 4   4623.711739 -999.000000              -999     2.895991  145.921799
# 5   4630.271739    0.082269              -999     2.831982  113.233625
# 6   4636.831739 -999.000000              -999     2.774357  113.594556
# 7   4643.391739    0.062989              -999     2.727031  121.931755
# 8   4649.951739 -999.000000              -999     2.926972  121.318158
# 9   4656.511739    0.067931              -999     2.974074  140.274713
# 10  4663.071739 -999.000000              -999     2.496010  124.821073
# 11  4669.631739    0.069750              -999     2.819388   85.366831
# ...

# %%
#open the acoustic impedence data
df_AI = pd.read_csv("AI.csv")

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)
# 0               6248.696838           6289.521004
# ...

# %%
df_AI.columns
# Out:
# Index(['X(ft)', 'Y(ft)', 'AI_lower(2012-01-01)', 'AI_upper(2012-01-01)',
#        'AI_lower(2021-12-20)', 'AI_upper(2021-12-20)'],
#       dtype='object')

# %%
#find the difference between lower zone 2021 and 2012
df_AI["lower_diff_year"] = df_AI['AI_lower(2021-12-20)'] - df_AI['AI_lower(2012-01-01)']

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year
# ...

# %%
#find the difference between upper zone 2012 and 2021
df_AI["upper_diff_year"] = df_AI['AI_upper(2021-12-20)'] - df_AI['AI_upper(2012-01-01)']

# %%
df_AI["upper_diff_year"]
# Out:
# 0        25.757784
# 1        25.708269
# 2        25.554874
# 3        25.307272
# 4        24.967225
#            ...
# 51195   -11.569660
# 51196   -11.892639
# 51197   -12.125806
# 51198   -12.268385
# 51199   -12.316070
# Name: upper_diff_year, Length: 51200, dtype: float64

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year  \
# ...

# %%
#create heat maps to view the impedence values in 2012 and 2021
#modified from https://seaborn.pydata.org/generated/seaborn.heatmap.html

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_lower(2012-01-01)')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing impedence in lower interval 2012')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_lower(2021-12-20)')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing impedence in lower interval 2021')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_upper(2012-01-01)')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing impedence in upper interval 2012')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'AI_upper(2021-12-20)')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing impedence in upper interval 2021')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'lower_diff_year')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing difference in impedence between lower 2012 and lower 2021')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

table = df_AI.pivot('X(ft)', 'Y(ft)', 'upper_diff_year')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.title('Heat Map showing difference in impedence between upper 2012 and upper 2021')
# save figure
plt.savefig('seabornPandas.png', dpi=100)
plt.show()

# %%
df_wells = pd.read_csv("Well_Head_and_Completion.csv") #read the well head data

# %%
df_wells
# Out:
#     WELL      X(ft)     Y(ft) Completion  Elevation Kelly Bushing (ft)
# 0    WP0  137106.82  83818.47      Upper                        193.32
# 1    WP1  132460.98  85832.77      Upper                        187.15
# 2    WP2  133634.00  82144.52      Upper                        164.55
# 3    WP3  140892.57  81747.12      Lower                        179.92
# 4    WP4  109951.43  89343.45      Lower                        186.21
# 5    WP5  123950.95  92227.31      Lower                        172.80
# 6    WP6  111035.32  88692.32      Lower                        182.66
# 7    WP7  112439.69  85560.85      Lower                        181.09
# 8    WP8  127369.74  91739.99      Upper                        180.04
# 9    WP9  115943.69  86730.44      Lower                        178.25
# 10  WP10  134042.86  82411.27      Upper                        184.33
# 11  WP11  115725.49  86866.60      Upper                        192.03
# ...

# %%
#plot the well data on the threshold values of impedence
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1)
#color = ['green' if diff > 80 else 'blue' for diff in df_AI['lower_diff_year']]
color = ['green' if val > 6400 else 'blue' for val in df_AI['AI_lower(2012-01-01)']]
classes = ['black:lower','red:upper']
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05, label = classes)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.title("Map showing the boundary(within impedence threshold) for wells")
plt.legend()
plt.show()

color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1,label = classes)
color = ['green' if diff > 80 else 'blue' for diff in df_AI['lower_diff_year']]
#color = ['green' if val > 6400 else 'blue' for val in df_AI['AI_lower(2012-01-01)']]
classes = ['black:lower','red:upper']
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.title("Map showing potentially depleted regions in green patches")
plt.legend()
plt.show()

# coordinates for center
# clat = df_wells["Latitude"].mean()
# clon = df_wells["Longitude"].mean()

# # create map
# m = folium.Map(location=[clat,clon], zoom_start=15)

# # display
# display(m)
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1)
color = ['green' if val > 6400 else 'blue' for val in df_AI['AI_upper(2012-01-01)']]
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.title("Map showing")
plt.show()

color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells['Completion']]
plt.scatter(df_wells['Y(ft)'], df_wells['X(ft)'] , s=10, c=color, alpha=1)
color = ['green' if diff > 30 else 'blue' for diff in df_AI['upper_diff_year']]
plt.scatter(df_AI['Y(ft)'], df_AI['X(ft)'] , s=10, c=color, alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.show()

# %%
def split_upper_lower(df, column_names):
    upper_lower = [df, 0, 0]
    zone = column_names[12]
    upper_lower[1] = df[df[zone] == 'Upper']
    upper_lower[2] = df[df[zone] == 'Lower']
    return upper_lower


# Code modified from https://thispointer.com/count-number-of-zeros-in-pandas-dataframe-column/
# Replace -999 with 0 and count how many times it appears per column
def count_and_replace(df, column):
    nan_count = 0
    if column != 'Zone':
        df.loc[df[column] < -990, column] = -999
    if -999 in set(df[column]):
        nan_count = df[column].value_counts()[-999]
    df[column] = df[column].replace(-999, 0)
    return nan_count


def plot_nan_frequencies(df, column_names, nan_count_list):
    nan_percents = []
    for col in range(len(nan_count_list)):
        nan_percents.append(nan_count_list[col]/len(df))
        
    plt.bar(column_names, nan_percents, color = 'darkorange', align = 'center') 
    plt.subplots_adjust(left=0.0, bottom=0.0, right=3.2, top=1.2, wspace=0.2, hspace=0.2)
    plt.title('Data Completeness') 
    plt.ylabel('Percentage of Missing Records') 
    plt.xlabel('Feature')  
    plt.show()


def read_well_logs():

    # Code modified from https://www.geeksforgeeks.org/how-to-read-all-csv-files-in-a-folder-in-pandas/
    # use glob to get all the csv files in the folder
    path = str(os.getcwd()) + '/Well_Log'
    joined_csv = glob.glob(os.path.join(path, "WP*.csv"))

    df = pd.concat(map(pd.read_csv, joined_csv), ignore_index=True)

    # Code copied from https://www.geeksforgeeks.org/iterating-over-rows-and-columns-in-pandas-dataframe/
    column_names = df.columns.values.tolist()
    upper_lower = split_upper_lower(df, column_names)

    for zone in range(len(upper_lower)):
        print('***************************************************')
        if zone == 0:
            print('TOTAL')
        elif zone == 1:
            print('UPPER')
        else:
            print('LOWER')

        nan_count_list = []
        for column in column_names:
            nan_count = count_and_replace(upper_lower[zone], column)
            nan_count_list.append(nan_count)
    
        # print the content
        print('Content:')
        print(upper_lower[zone])

        for idx in range(len(column_names)):
            if nan_count_list[idx] != 0:
                print(column_names[idx], '--- nan count:', nan_count_list[idx])
        
        print()
        print(upper_lower[zone].describe().T)
        print(path)
        plot_nan_frequencies(upper_lower[zone], column_names, nan_count_list)
        print()
        print() 
        print()   


#def main():
# if __name__ == '__main__':
#     main()

# %%
read_well_logs()
# Out:
# ***************************************************
# TOTAL
# Content:
#            MD(ft)  PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# 0     4597.471739   0.000000               0.0     2.700700   75.056761
# 1     4604.031739   0.087413               0.0     2.819380   85.369586
# 2     4610.591739   0.000000               0.0     2.798909  124.121043
# 3     4617.151739   0.059590               0.0     2.575396  114.571242
# 4     4623.711739   0.000000               0.0     2.895991  145.921799
# ...           ...        ...               ...          ...         ...
# 1958  4684.875411   0.000000               0.0     2.461998    0.000000
# 1959  4691.435411   0.000000               0.0     2.454321    0.000000
# 1960  4697.995411   0.000000               0.0     2.539750    0.000000
# 1961  4704.555411   0.000000               0.0     2.467592    0.000000
# 1962  4711.115411   0.000000               0.0     2.536990    0.000000
#
# ...

# %%
df_production = pd.read_csv("Production_History_Field.csv") #read the production history file

# %%
df_production
# Out:
#          Date  WOPR:WP0(bbl/day)  WOPR:WP1(bbl/day)  WOPR:WP10(bbl/day)  \
# 0    1-Jan-12           8.945508                0.0            0.000000
# 1    1-Feb-12           8.854879                0.0            0.000000
# 2    1-Mar-12           8.845839                0.0            0.000000
# 3    1-Apr-12           8.839578                0.0            0.000000
# 4    1-May-12           8.834659                0.0            0.000000
# ..        ...                ...                ...                 ...
# 116  1-Sep-21           0.000000                0.0           45.614398
# 117  1-Oct-21           0.000000                0.0           45.574879
# 118  1-Nov-21           0.000000                0.0           45.537784
# 119  1-Dec-21           0.000000                0.0           45.500584
# 120  1-Jan-22           0.000000                0.0           45.500584
#
#      WOPR:WP11(bbl/day)  WOPR:WP12(bbl/day)  WOPR:WP13(bbl/day)  \
# ...

# %%
#extract the well information and calculate the mean monthly production and total production
list_prod_mean =[]
list_prod_sum = []
list_wells = []
i=0
for column in df_production.columns[1:df_production.shape[1]]:
    list_wells.append(column.split(':')[1].split('(')[0])
    list_prod_mean.append((df_production[column].loc[df_production[column] != 0]).mean())
    list_prod_sum.append(df_production[column].sum())
df_prod = pd.DataFrame(list(zip(list_wells,list_prod_mean,list_prod_sum)), columns=['WELL','Mean Monthly Prod', 'Total Prod'])
df_prod
# Out:
#     WELL  Mean Monthly Prod     Total Prod
# 0    WP0           8.809168     475.695080
# 1    WP1          38.675641    1005.566662
# 2   WP10          46.363101    1576.345443
# 3   WP11                NaN       0.000000
# 4   WP12           0.664632      57.822977
# 5   WP13          22.342583    1787.406680
# 6   WP14         381.194628   17534.952878
# 7   WP15        3060.205978   45903.089669
# 8   WP16        1221.216449   53733.523751
# 9   WP17        1367.727037   17780.451483
# 10  WP18         291.086371   27653.205286
# 11  WP19           7.082097     354.104875
# 12   WP2           5.276535     443.228898
# 13  WP20          39.545986     870.011682
# 14  WP21           1.579448      60.019034
# 15  WP22          13.159516     342.147423
# 16  WP23           6.300324     497.725573
# 17  WP24          90.374282    4880.211255
# 18  WP25        1328.452893   18598.340498
# 19  WP26         439.336342   18012.790032
# 20  WP27           9.066930     471.480349
# ...

# %%
df_wells_prod = df_prod.merge(df_wells, how ='right')
df_wells_prod

#df_wells_prod[['Total Prod']].sort_values()
# Out:
#     WELL  Mean Monthly Prod     Total Prod      X(ft)     Y(ft) Completion  \
# 0    WP0           8.809168     475.695080  137106.82  83818.47      Upper
# 1    WP1          38.675641    1005.566662  132460.98  85832.77      Upper
# 2    WP2           5.276535     443.228898  133634.00  82144.52      Upper
# 3    WP3        1606.279426   88345.368434  140892.57  81747.12      Lower
# 4    WP4         257.113535    8484.746653  109951.43  89343.45      Lower
# 5    WP5          13.723622    1056.718880  123950.95  92227.31      Lower
# 6    WP6        1033.318772   30999.563162  111035.32  88692.32      Lower
# 7    WP7           5.925703      71.108432  112439.69  85560.85      Lower
# 8    WP8          13.095474     654.773717  127369.74  91739.99      Upper
# 9    WP9           6.434229     263.803390  115943.69  86730.44      Lower
# 10  WP10          46.363101    1576.345443  134042.86  82411.27      Upper
# ...

# %%
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells_prod['Completion']]
plt.scatter(df_wells_prod['Y(ft)'], df_wells_prod['X(ft)'] , s=df_wells_prod['Mean Monthly Prod']/10, c=color, alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.title("Map showing mean monthly production during operation of wells")
# plt.legend(('black', 'red'),
#            ('Lower interval', 'Upper interval'),
#            scatterpoints=1,
#            loc='lower left',
#            ncol=3,
#            fontsize=8)

plt.show()

# %%
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells_prod['Completion']]
plt.scatter(df_wells_prod['Y(ft)'], df_wells_prod['X(ft)'] , s=df_wells_prod['Total Prod']/100, c=color, alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.title("Map showing total production of wells")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# Replaces -999 values with NaN
def make_nan(df):
    column_names = df.columns.values.tolist() # List of column names
    for column in column_names:
        if column != 'Zone': # Filled with strings so it can cause error
            df.loc[df[column] < -997, column] = np.nan # Replace -999 with NaN
        

def process_well_logs():

    # Code modified from https://www.geeksforgeeks.org/how-to-read-all-csv-files-in-a-folder-in-pandas/
    # Get CSV files from Well_Log folder
    path = str(os.getcwd()) + '/Well_Log'
    all_logs = glob.glob(os.path.join(path, "WP*.csv"))

    # Store all well log info
    well_log_data = [ [0]*12 for _ in range(50) ]
    column_headers = [0] * 12

    # Loop through each log individually
    for well_log in range(len(all_logs)):
        df = pd.read_csv(all_logs[well_log])
        # well_name = all_logs[well_log].split('\\')[-1].split('.')[0]
        column_headers = df.columns
        column_headers = column_headers[:-1]

        # Convert -999 to NaN
        make_nan(df)

        # Get mean values for each well feature
        feature_means = df.mean(numeric_only=True).T

        # Append feature_means[index] into data_list[well][index]
        for feature in range(len(feature_means)):
            if feature != 12: # Don't have a mean for 'Zone' value
                well_log_data[well_log][feature] = feature_means[feature]
    
    # Create a dataframe with the mean values
    mean_df = pd.DataFrame(well_log_data, columns = column_headers)
    print(mean_df)
    return mean_df
#     # Get path to csv file with production info
#     production_csv_path = str(os.getcwd()) + '\Well_Head_and_Completion_Aggprod.csv'  
#     production_df = pd.read_csv(production_csv_path)

#     # Combine the dataframes
#     combined_df = pd.concat([production_df, mean_df.set_index(production_df.index)], axis=1)
#     print(combined_df)

# %%
df_well_logs = process_well_logs()
# Out:
#          MD(ft)  PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# 0   4725.391739   0.128137               NaN     2.570550  130.203580
# 1   4868.900545        NaN               NaN     2.469263         NaN
# 2   4818.174657   0.123507          3.681348     2.392931         NaN
# 3   4661.109023   0.099223          0.453895     2.544808  110.119546
# 4   4808.270995        NaN               NaN     2.470077  143.509402
# 5   4531.991055        NaN               NaN     2.470225  135.242368
# 6   4781.602978   0.138346               NaN     2.476446         NaN
# 7   4405.841183   0.172151               NaN     2.342374         NaN
# 8   4562.928038   0.144393               NaN     2.482244         NaN
# 9   4600.599989        NaN               NaN     2.351391         NaN
# 10  4552.206377   0.172699               NaN     2.225759         NaN
# 11  4359.205683   0.124681          5.741535     2.532609  122.044220
# ...

# %%
#final merged dataset
df_processed = df_wells_prod.merge(df_well_logs, how='right', left_index=True, right_index=True)
df_processed
# Out:
#     WELL  Mean Monthly Prod     Total Prod      X(ft)     Y(ft) Completion  \
# 0    WP0           8.809168     475.695080  137106.82  83818.47      Upper
# 1    WP1          38.675641    1005.566662  132460.98  85832.77      Upper
# 2    WP2           5.276535     443.228898  133634.00  82144.52      Upper
# 3    WP3        1606.279426   88345.368434  140892.57  81747.12      Lower
# 4    WP4         257.113535    8484.746653  109951.43  89343.45      Lower
# 5    WP5          13.723622    1056.718880  123950.95  92227.31      Lower
# 6    WP6        1033.318772   30999.563162  111035.32  88692.32      Lower
# 7    WP7           5.925703      71.108432  112439.69  85560.85      Lower
# 8    WP8          13.095474     654.773717  127369.74  91739.99      Upper
# 9    WP9           6.434229     263.803390  115943.69  86730.44      Lower
# 10  WP10          46.363101    1576.345443  134042.86  82411.27      Upper
# ...

# %%
df_processed.transpose()
# Out:
#                                        0            1            2   \
# WELL                                  WP0          WP1          WP2
# Mean Monthly Prod                8.809168    38.675641     5.276535
# Total Prod                      475.69508  1005.566662   443.228898
# X(ft)                           137106.82    132460.98     133634.0
# Y(ft)                            83818.47     85832.77     82144.52
# Completion                          Upper        Upper        Upper
# Elevation Kelly Bushing (ft)       193.32       187.15       164.55
# MD(ft)                        4725.391739  4868.900545  4818.174657
# PORO(v/v)                        0.128137          NaN     0.123507
# Permeability(mD)                      NaN          NaN     3.681348
# RHOB(g/cm3)                       2.57055     2.469263     2.392931
# DTS(us/ft)                      130.20358          NaN          NaN
# DT(us/ft)                       75.877758    92.942081    86.678756
# ...

# %%
#code modified from https://github.com/PGEHackathon/workshop/blob/main/03_feature_selection/workflows/SubsurfaceDataAnalytics_Feature_Ranking.ipynb
sns.pairplot(df_processed,vars=['PORO(v/v)','Permeability(mD)','RHOB(g/cm3)','DTS(us/ft)','DT(us/ft)', 'PEF(B/E)','RD(OHMM)','RS(OHMM)','ROP','DENC(g/cm3)','NPHI(v/v)'],markers='o')

# %%
df_processed.iloc[:,8:19].corr()
# Out:
#                   PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# PORO(v/v)          1.000000          0.458417    -0.787186    0.358341
# Permeability(mD)   0.458417          1.000000    -0.466875    0.286281
# RHOB(g/cm3)       -0.787186         -0.466875     1.000000   -0.016734
# DTS(us/ft)         0.358341          0.286281    -0.016734    1.000000
# DT(us/ft)          0.529153          0.160251    -0.630459    0.632505
# PEF(B/E)          -0.142660          0.069104     0.145179   -0.476410
# RD(OHMM)          -0.621153         -0.242325     0.356832   -0.397155
# RS(OHMM)           0.172569          0.247628    -0.134510   -0.202336
# ROP               -0.263467          0.307298     0.005285   -0.122854
# DENC(g/cm3)       -0.311660         -0.233807     0.811498   -0.064980
# NPHI(v/v)          0.398585          0.018262    -0.413529    0.533328
#
#                   DT(us/ft)  PEF(B/E)  RD(OHMM)  RS(OHMM)       ROP  \
# ...

# %%
#feature selection using correlation
plt.subplot(111)                          # plot a color coded correlation matrix
sns.heatmap(df_processed.iloc[:,8:19].corr(),vmin = -1.0, vmax = 1.0,linewidths=.5, fmt= '.1f')
plt.subplots_adjust(left=0.0, bottom=0.0, right=1.5, top=1.5, wspace=0.2, hspace=0.2)
plt.show()

# %%
df_subset_processed = df_processed[['PORO(v/v)','Permeability(mD)','RHOB(g/cm3)','DTS(us/ft)','DT(us/ft)', 'PEF(B/E)','RD(OHMM)','RS(OHMM)','ROP','DENC(g/cm3)','NPHI(v/v)','Total Prod']]
#df_subset_processed = df_processed
plt.subplot(111)                          # plot a color coded correlation matrix
sns.heatmap(df_subset_processed.corr(),vmin = -1.0, vmax = 1.0,linewidths=.5, fmt= '.1f')
plt.subplots_adjust(left=0.0, bottom=0.0, right=1.5, top=1.5, wspace=0.2, hspace=0.2)
plt.show()
df_subset_processed.corr()
# Out:
#                   PORO(v/v)  Permeability(mD)  RHOB(g/cm3)  DTS(us/ft)  \
# PORO(v/v)          1.000000          0.458417    -0.787186    0.358341
# Permeability(mD)   0.458417          1.000000    -0.466875    0.286281
# RHOB(g/cm3)       -0.787186         -0.466875     1.000000   -0.016734
# DTS(us/ft)         0.358341          0.286281    -0.016734    1.000000
# DT(us/ft)          0.529153          0.160251    -0.630459    0.632505
# PEF(B/E)          -0.142660          0.069104     0.145179   -0.476410
# RD(OHMM)          -0.621153         -0.242325     0.356832   -0.397155
# RS(OHMM)           0.172569          0.247628    -0.134510   -0.202336
# ROP               -0.263467          0.307298     0.005285   -0.122854
# DENC(g/cm3)       -0.311660         -0.233807     0.811498   -0.064980
# NPHI(v/v)          0.398585          0.018262    -0.413529    0.533328
# Total Prod        -0.137344         -0.187999    -0.121643   -0.227288
#
# ...

# %%
color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells_prod['Completion']]
plt.scatter(df_processed['Y(ft)'], df_processed['X(ft)'] , s=(df_processed['RHOB(g/cm3)']-df_processed['RHOB(g/cm3)'].mean())*1000, c=color, alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.show()

color = ['red' if (comp == 'Upper') else 'black' for comp in df_wells_prod['Completion']]
plt.scatter(df_processed['Y(ft)'], df_processed['X(ft)'] , s=(df_processed['RD(OHMM)']-df_processed['RD(OHMM)'].mean())*10, c=color, alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.show()
# Out:
# C:\Users\benja\anaconda3\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df_processed.describe()
# Out:
#        Mean Monthly Prod     Total Prod          X(ft)         Y(ft)  \
# count          49.000000      50.000000      50.000000     50.000000
# mean          524.859474   19767.902630  124976.771600  87616.738200
# std           689.315691   36512.094484    9948.690682   3299.595523
# min             0.142503       0.000000  109560.260000  81747.120000
# 25%             9.066930     376.385881  115954.590000  84687.942500
# 50%           257.113535    6682.478954  124027.505000  87780.815000
# 75%          1033.318772   28186.926729  133954.012500  90481.025000
# max          3060.205978  232777.797780  142095.820000  93691.550000
#
#        Elevation Kelly Bushing (ft)       MD(ft)  PORO(v/v)  Permeability(mD)  \
# count                     50.000000    50.000000  23.000000         11.000000
# mean                     181.025000  4670.693222   0.127648          9.662408
# std                        9.100926   143.292950   0.026689          8.210335
# ...

# %%
# df_processed['RHOB(g/cm3)_fill'] = df_processed['RHOB(g/cm3)'].fillna(df_processed['RHOB(g/cm3)'].mean())
# df_processed['PEF(B/E)_fill'] = df_processed['PEF(B/E)'].fillna(df_processed['PEF(B/E)'].mean())
# df_processed['RD(OHMM)_fill'] = df_processed['RD(OHMM)'].fillna(df_processed['RD(OHMM)'].mean())
# df_processed['ROP_fill'] = df_processed['ROP'].fillna(df_processed['ROP'].mean())
# df_processed['RS(OHMM)_fill'] = df_processed['RS(OHMM)'].fillna(df_processed['RS(OHMM)'].mean())

df_processed['RHOB(g/cm3)_fill'] = df_processed['RHOB(g/cm3)'].fillna(0)
df_processed['PEF(B/E)_fill'] = df_processed['PEF(B/E)'].fillna(0)
df_processed['RD(OHMM)_fill'] = df_processed['RD(OHMM)'].fillna(0)
df_processed['ROP_fill'] = df_processed['ROP'].fillna(0)
df_processed['RS(OHMM)_fill'] = df_processed['RS(OHMM)'].fillna(0)

# df_processed['RHOB(g/cm3)_fill'] = df_processed['RHOB(g/cm3)'].fillna(df_processed['RHOB(g/cm3)'].mean())
# df_processed['PEF(B/E)_fill'] = df_processed['PEF(B/E)'].fillna(df_processed['PEF(B/E)'].mean())
# df_processed['RD(OHMM)_fill'] = df_processed['RD(OHMM)'].fillna(df_processed['RD(OHMM)'].mean())
# df_processed['ROP_fill'] = df_processed['ROP'].fillna(df_processed['ROP'].mean())
# df_processed['RS(OHMM)_fill'] = df_processed['RS(OHMM)'].fillna(df_processed['RS(OHMM)'].mean())

#df_processed = df_processed.fillna(0)
df_processed_lower= df_processed[df_processed['Completion'] == 'Lower']
#df_processed_lower
df_processed_upper= df_processed[df_processed['Completion'] == 'Upper']
df_processed_upper
# Out:
#     WELL  Mean Monthly Prod    Total Prod      X(ft)     Y(ft) Completion  \
# 0    WP0           8.809168    475.695080  137106.82  83818.47      Upper
# 1    WP1          38.675641   1005.566662  132460.98  85832.77      Upper
# 2    WP2           5.276535    443.228898  133634.00  82144.52      Upper
# 8    WP8          13.095474    654.773717  127369.74  91739.99      Upper
# 10  WP10          46.363101   1576.345443  134042.86  82411.27      Upper
# 11  WP11                NaN      0.000000  115725.49  86866.60      Upper
# 13  WP13          22.342583   1787.406680  119311.27  89234.02      Upper
# 18  WP18         291.086371  27653.205286  117798.78  90645.70      Upper
# 19  WP19           7.082097    354.104875  110189.22  86209.71      Upper
# 20  WP20          39.545986    870.011682  133687.47  83554.44      Upper
# 21  WP21           1.579448     60.019034  121120.49  87804.64      Upper
# 22  WP22          13.159516    342.147423  115987.29  91854.91      Upper
# ...

# %%
#run a regression to find coefficient values
import pandas
from sklearn import linear_model
regr = linear_model.LinearRegression()

df_processed = df_processed_lower
X = df_processed[["RHOB(g/cm3)_fill","PEF(B/E)_fill","RD(OHMM)_fill","ROP_fill",'RS(OHMM)_fill']]
#X = df_processed[["RHOB(g/cm3)_fill","PEF(B/E)_fill","ROP_fill",'RS(OHMM)_fill']]
y = df_processed[["Total Prod"]]
regr.fit(X, y)



print(regr.coef_)
# Out:
# [[-8.05966502e+03 -1.04714743e+03  1.31128864e+02  1.28794203e+02
#    3.86139708e+00]]

# %%
#create a 2D interpolation 
from scipy.interpolate import interp2d
# frhob = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RHOB(g/cm3)_fill'], kind='linear', fill_value=df_processed['RHOB(g/cm3)_fill'].mean())
# fpef = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['PEF(B/E)_fill'], kind='linear', fill_value=df_processed['PEF(B/E)_fill'].mean())
# frd = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RD(OHMM)_fill'], kind='linear', fill_value=df_processed['RD(OHMM)_fill'].mean())
# frop = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['ROP_fill'], kind='linear', fill_value=df_processed['ROP_fill'].mean())
# frs = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RS(OHMM)_fill'], kind='linear', fill_value=df_processed['RS(OHMM)_fill'].mean())

frhob = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RHOB(g/cm3)_fill'], kind='linear')
fpef = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['PEF(B/E)_fill'], kind='linear')
frd = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RD(OHMM)_fill'], kind='linear')
frop = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['ROP_fill'], kind='linear')
frs = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RS(OHMM)_fill'], kind='linear')

# frhob = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RHOB(g/cm3)_fill'], kind='cubic')
# fpef = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['PEF(B/E)_fill'], kind='cubic')
# frd = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RD(OHMM)_fill'], kind='cubic')
# frop = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['ROP_fill'], kind='cubic')
# frs = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RS(OHMM)_fill'], kind='cubic')
# #Let's say we want to interpolate "Pa" values at:
# x_prime, y_prime = (90000, 120000)

# # Just plug the new coords into your function
# pa_new = frhob(x_prime, y_prime)
# pa_new
# Out:
# C:\Users\benja\anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:977: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=6,10 m=30 fp=0.004816 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# C:\Users\benja\anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:977: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=8,8 m=30 fp=4.846219 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# C:\Users\benja\anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:977: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# ...

# %%
df_AI
# Out:
#            X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0      109397.84  99193.76           6245.484387           6263.763220
# 1      109397.84  99062.56           6245.727488           6263.944840
# 2      109397.84  98931.36           6246.111283           6264.050487
# 3      109397.84  98800.16           6246.627959           6264.078733
# 4      109397.84  98668.96           6247.270327           6264.039096
# ...          ...       ...                   ...                   ...
# 51195  142853.84  73609.76           6334.401793           6260.202243
# 51196  142853.84  73478.56           6335.324532           6259.040527
# 51197  142853.84  73347.36           6336.350363           6257.905630
# 51198  142853.84  73216.16           6337.487009           6256.806460
# 51199  142853.84  73084.96           6338.736362           6255.746525
#
#        AI_lower(2021-12-20)  AI_upper(2021-12-20)  lower_diff_year  \
# ...

# %%
#divide the data into upper and lower interval
df_AI_lower = df_AI[(df_AI['AI_lower(2012-01-01)']> 6400) & (df_AI['lower_diff_year'] < 80)].reset_index()
df_AI_lower
# Out:
#        index      X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0         56  109397.84  91846.56           6405.762254           6388.173327
# 1         57  109397.84  91715.36           6412.119400           6393.552210
# 2         58  109397.84  91584.16           6418.501984           6399.039858
# 3         59  109397.84  91452.96           6424.889619           6404.628107
# 4         60  109397.84  91321.76           6431.261925           6410.296693
# ...      ...        ...       ...                   ...                   ...
# 13402  51143  142853.84  80432.16           6436.842296           6433.716210
# 13403  51144  142853.84  80300.96           6428.193115           6427.810699
# 13404  51145  142853.84  80169.76           6419.571989           6421.711430
# 13405  51146  142853.84  80038.56           6411.006804           6415.435296
# 13406  51147  142853.84  79907.36           6402.524199           6409.007685
#
# ...

# %%
#thresholding AI to find potential new well locations
df_AI_upper = df_AI[(df_AI['AI_upper(2012-01-01)']> 6400) & (df_AI['upper_diff_year'] < 30)].reset_index()
df_AI_upper
# Out:
#        index      X(ft)     Y(ft)  AI_lower(2012-01-01)  AI_upper(2012-01-01)  \
# 0         59  109397.84  91452.96           6424.889619           6404.628107
# 1         60  109397.84  91321.76           6431.261925           6410.296693
# 2         61  109397.84  91190.56           6437.596133           6416.026809
# 3         62  109397.84  91059.36           6443.873137           6421.793928
# 4         63  109397.84  90928.16           6450.070908           6427.575366
# ...      ...        ...       ...                   ...                   ...
# 15093  51144  142853.84  80300.96           6428.193115           6427.810699
# 15094  51145  142853.84  80169.76           6419.571989           6421.711430
# 15095  51146  142853.84  80038.56           6411.006804           6415.435296
# 15096  51147  142853.84  79907.36           6402.524199           6409.007685
# 15097  51148  142853.84  79776.16           6394.157442           6402.452286
#
# ...

# %%
#thresholding AI to find potential new well locations in lower
plt.scatter(df_AI_lower['Y(ft)'], df_AI_lower['X(ft)'] , s=10, c='red', alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.show()

# %%
#thresholding AI to find potential new well locations in Upper
plt.scatter(df_AI_upper['Y(ft)'], df_AI_upper['X(ft)'] , s=10, c='red', alpha=0.05)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.show()

# %%
#Interpolate well features at new positions 
list_rhob=[]
list_pef=[]
list_rd=[]
list_rop=[]
list_rs=[]
list_monthly = []
list_twoyearly = []
for i in range(len(df_AI_lower)):
    #print(df_AI_lower.index[i])
    rhob=frhob(df_AI_lower['Y(ft)'][i],df_AI_lower['X(ft)'][i])[0]
    pef=fpef(df_AI_lower['Y(ft)'][i],df_AI_lower['X(ft)'][i])[0]
    rd=frd(df_AI_lower['Y(ft)'][i],df_AI_lower['X(ft)'][i])[0]
    rop=frop(df_AI_lower['Y(ft)'][i],df_AI_lower['X(ft)'][i])[0]
    rs=frs(df_AI_lower['Y(ft)'][i],df_AI_lower['X(ft)'][i])[0]
    
#     if rhob < df_processed['RHOB(g/cm3)'].min():
#         rhob = df_processed['RHOB(g/cm3)'].min()
#     if rhob > df_processed['RHOB(g/cm3)'].max():
#         rhob = df_processed['RHOB(g/cm3)'].max()
#     if pef < df_processed['PEF(B/E)'].min():
#         pef = df_processed['PEF(B/E)'].min()
#     if pef > df_processed['PEF(B/E)'].max():
#         pef = df_processed['PEF(B/E)'].max()
#     if rd < df_processed['RD(OHMM)'].min():
#         rd = df_processed['RD(OHMM)'].min()
#     if rd > df_processed['RD(OHMM)'].max():
#         rd = df_processed['RD(OHMM)'].max()
#     if rop < df_processed['ROP'].min():
#         rop = df_processed['ROP'].min()
#     if rop > df_processed['ROP'].max():
#         rop = df_processed['ROP'].max()
#     if rs < df_processed['RS(OHMM)'].min():
#         rs = df_processed['RS(OHMM)'].min()
#     if rs > df_processed['RS(OHMM)'].max():
#         rs = df_processed['RS(OHMM)'].max()

#Predict production based on regression coefficients and interpolated well features. Multiply by 24 to get 2 year cumulative
    production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rd + regr.coef_[0][3]*rop + regr.coef_[0][4]*rs
    #monthly_production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rop + regr.coef_[0][3]*rs
    two_year_prod = 24*monthly_production
    
    list_rhob.append(rhob)
    list_pef.append(pef)
    list_rd.append(rd)
    list_rop.append(rop)
    list_rs.append(rs)
    list_monthly.append(monthly_production)
    list_twoyearly.append(two_year_prod)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44320/1444549541.py in <module>
#      39     production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rd + regr.coef_[0][3]*rop + regr.coef_[0][4]*rs
#      40     #monthly_production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rop + regr.coef_[0][3]*rs
# ---> 41     two_year_prod = 24*monthly_production
#      42
#      43     list_rhob.append(rhob)
#
# NameError: name 'monthly_production' is not defined

# %%
df_AI_lower['2-Year Cumulative Production (bbl)'] = list_twoyearly
df_AI_lower['monthly production'] = list_monthly
df_AI_lower['rhob'] = list_rhob
df_AI_lower ['pef'] = list_pef
df_AI_lower ['rd'] = list_rd
df_AI_lower ['rop'] = list_rop
df_AI_lower ['rs'] = list_rs

# %%
#Create df with top 3 well locations
df_AI_top3_lower =df_AI_lower.sort_values('2-Year Cumulative Production (bbl)', ascending=False).head(20)

# %%
#Final Result Used for the csv output !!!
df_AI_top3_lower

# %%
#Predicted well locations shown
plt.scatter(df_AI_lower['Y(ft)'], df_AI_lower['X(ft)'] , s=10, c='red', alpha=0.05)
plt.scatter(df_AI_top10['Y(ft)'], df_AI_top10['X(ft)'] , s=10, c='red', alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.show()

# %%
    #Test regression coefficients on existing well - validation only
    Ytest=89895.78
    Xtest=115684.27
    rhob=frhob(Ytest,Xtest)[0]
    pef=fpef(Ytest,Xtest)[0]
    rd=frd(Ytest,Xtest)[0]
    rop=frop(Ytest,Xtest)[0]
    rs=frs(Ytest,Xtest)[0]
    monthly_production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rd + regr.coef_[0][3]*rop + regr.coef_[0][4]*rs
    two_year_prod = 24*monthly_production
    monthly_production

# %%
#Run similar regression for upper interval
regr = linear_model.LinearRegression()

df_processed = df_processed_upper
X = df_processed[["RHOB(g/cm3)_fill","PEF(B/E)_fill","RD(OHMM)_fill","ROP_fill",'RS(OHMM)_fill']]
#X = df_processed[["RHOB(g/cm3)_fill","PEF(B/E)_fill","ROP_fill",'RS(OHMM)_fill']]
y = df_processed[["Total Prod"]]
regr.fit(X, y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
# predictedCO2 = regr.predict([[2300, 1300]])

print(regr.coef_)

# %%
#Interpolation equations for parameters
frhob = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RHOB(g/cm3)_fill'], kind='linear')
fpef = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['PEF(B/E)_fill'], kind='linear')
frd = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RD(OHMM)_fill'], kind='linear')
frop = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['ROP_fill'], kind='linear')
frs = interp2d(df_processed['Y(ft)'], df_processed['X(ft)'], df_processed['RS(OHMM)_fill'], kind='linear')

# %%
#Interpolate well features at new positions
list_rhob=[]
list_pef=[]
list_rd=[]
list_rop=[]
list_rs=[]
list_monthly = []
list_twoyearly = []
for i in range(len(df_AI_upper)):
    #print(df_AI_lower.index[i])
    rhob=frhob(df_AI_upper['Y(ft)'][i],df_AI_upper['X(ft)'][i])[0]
    pef=fpef(df_AI_upper['Y(ft)'][i],df_AI_upper['X(ft)'][i])[0]
    rd=frd(df_AI_upper['Y(ft)'][i],df_AI_upper['X(ft)'][i])[0]
    rop=frop(df_AI_upper['Y(ft)'][i],df_AI_upper['X(ft)'][i])[0]
    rs=frs(df_AI_upper['Y(ft)'][i],df_AI_upper['X(ft)'][i])[0]
    
#     if rhob < df_processed['RHOB(g/cm3)'].min():
#         rhob = df_processed['RHOB(g/cm3)'].min()
#     if rhob > df_processed['RHOB(g/cm3)'].max():
#         rhob = df_processed['RHOB(g/cm3)'].max()
#     if pef < df_processed['PEF(B/E)'].min():
#         pef = df_processed['PEF(B/E)'].min()
#     if pef > df_processed['PEF(B/E)'].max():
#         pef = df_processed['PEF(B/E)'].max()
#     if rd < df_processed['RD(OHMM)'].min():
#         rd = df_processed['RD(OHMM)'].min()
#     if rd > df_processed['RD(OHMM)'].max():
#         rd = df_processed['RD(OHMM)'].max()
#     if rop < df_processed['ROP'].min():
#         rop = df_processed['ROP'].min()
#     if rop > df_processed['ROP'].max():
#         rop = df_processed['ROP'].max()
#     if rs < df_processed['RS(OHMM)'].min():
#         rs = df_processed['RS(OHMM)'].min()
#     if rs > df_processed['RS(OHMM)'].max():
#         rs = df_processed['RS(OHMM)'].max()
#Find monthly and yearly production estimates    
    monthly_production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rd + regr.coef_[0][3]*rop + regr.coef_[0][4]*rs
    #monthly_production = regr.coef_[0][0]*rhob + regr.coef_[0][1]*pef + regr.coef_[0][2]*rop + regr.coef_[0][3]*rs
    two_year_prod = 24*monthly_production
    
    list_rhob.append(rhob)
    list_pef.append(pef)
    list_rd.append(rd)
    list_rop.append(rop)
    list_rs.append(rs)
    list_monthly.append(monthly_production)
    list_twoyearly.append(two_year_prod)

# %%
df_AI_upper['2-Year Cumulative Production (bbl)'] = list_twoyearly
df_AI_upper['monthly production'] = list_monthly
df_AI_upper['rhob'] = list_rhob
df_AI_upper ['pef'] = list_pef
df_AI_upper ['rd'] = list_rd
df_AI_upper ['rop'] = list_rop
df_AI_upper ['rs'] = list_rs

# %%
#Find top 3 wells for the upper interval. 
#NOTE: These are not used as the cumulative production from this is out of range. 
#This may be because of the regression coefficients being too large, and because of only 20 well data in this interval
#Also, given the trend that Upper interval production << Lower interval production, we drop this result
df_AI_top3_upper =df_AI_upper.sort_values('2-Year Cumulative Production (bbl)', ascending=False).head(3)
df_AI_top3_upper

# %%
#Plot the positions of the predicted potential well sites in the upper interval.
plt.scatter(df_AI_upper['Y(ft)'], df_AI_upper['X(ft)'] , s=10, c='red', alpha=0.05)
plt.scatter(df_AI_top10['Y(ft)'], df_AI_top10['X(ft)'] , s=10, c='red', alpha=1)
plt.xlim(74000, 99000)
plt.ylim(109000, 144000)
plt.xlabel('Y(ft)')
plt.ylabel('X(ft)')
plt.show()
